# %% [markdown]
# #Build Ibound Arrays
# This notebook is used to build ibound arrays for individual model layers based on the extents of the units in the system and their relation to the layering strategy. Most of the layers will encompass the entire FAS extent; the glauconite-marker unit and Oldsmar permeable zone will be active only in south Florida.

# %% [markdown]
# ###Import modules and setup workspace

# %%
import os
import matplotlib.pyplot as plt
import paths
import fasgas_plotter
import fasgas_utils

# This is the model grid to be used
grid = r'..\gis\grids\grid_5000ft_v3\grid.shp'

# Read metadata associated with the model grid
ul_x, ul_y, delx, dely, nrow, ncol, rotation, proj4 = fasgas_utils.import_grid_metadata(grid)

# Format of the output ascii grid values
fmt = '%d'

fw_dir = r'dat\fw'
extent_dir = r'dat\extent'
ref_dir = r'ref'

# %% [markdown]
# ###Load extent arrays

# %%
ext_FAS = np.loadtxt(os.path.join(extent_dir, 'FASGAS_EXT_FAS.dat'))
ext_SAS = np.loadtxt(os.path.join(extent_dir, 'FASGAS_EXT_SAS.dat'))
ext_UCU = np.loadtxt(os.path.join(extent_dir, 'FASGAS_EXT_UCU.dat'))
ext_UPZ = np.loadtxt(os.path.join(extent_dir, 'FASGAS_EXT_UPZ.dat'))
ext_OCAPLPZ = np.loadtxt(os.path.join(extent_dir, 'FASGAS_EXT_OCAPLPZ.dat'))
ext_APPZ = np.loadtxt(os.path.join(extent_dir, 'FASGAS_EXT_APPZ.dat'))
ext_BCCU = np.loadtxt(os.path.join(extent_dir, 'FASGAS_EXT_BCCU.dat'))
ext_LISAPCU = np.loadtxt(os.path.join(extent_dir, 'FASGAS_EXT_LISAPCU.dat'))
ext_MAPCU = np.loadtxt(os.path.join(extent_dir, 'FASGAS_EXT_MAPCU.dat'))
ext_LAPPZ = np.loadtxt(os.path.join(extent_dir, 'FASGAS_EXT_LAPPZ.dat'))
ext_GLAUCU = np.loadtxt(os.path.join(extent_dir, 'FASGAS_EXT_GLAUCU.dat'))
ext_OLDSPZ = np.loadtxt(os.path.join(extent_dir, 'FASGAS_EXT_OLDSPZ.dat'))

# %% [markdown]
# ###Make ibound array for Layer 1

# %%
ibnd_l1 = ext_FAS
np.savetxt(os.path.join(ref_dir, 'fasgas_ibnd_L1.ref'), ibnd_l1, fmt=fmt)
fasgas_plotter.plot_image(array=ibnd_l1, title='ibound layer 1')

# %% [markdown]
# ###Make ibound array for Layer 2

# %%
ibnd_l2 = ext_FAS
np.savetxt(os.path.join(ref_dir, 'fasgas_ibnd_L2.ref'), ibnd_l2, fmt=fmt)
fasgas_plotter.plot_image(array=ibnd_l2, title='ibound layer 2')

# %% [markdown]
# ###Make ibound array for Layer 3

# %%
ibnd_l3 = ext_FAS
np.savetxt(os.path.join(ref_dir, 'fasgas_ibnd_L3.ref'), ibnd_l3, fmt=fmt)
fasgas_plotter.plot_image(array=ibnd_l3, title='ibound layer 3')

# %% [markdown]
# ###Make ibound array for Layer 4

# %%
ibnd_l4 = ext_FAS
np.savetxt(os.path.join(ref_dir, 'fasgas_ibnd_L4.ref'), ibnd_l4, fmt=fmt)
fasgas_plotter.plot_image(array=ibnd_l4, title='ibound layer 4')

# %% [markdown]
# ###Make ibound array for Layer 5

# %%
ibnd_l5 = ext_FAS
np.savetxt(os.path.join(ref_dir, 'fasgas_ibnd_L5.ref'), ibnd_l5, fmt=fmt)
fasgas_plotter.plot_image(array=ibnd_l5, title='ibound layer 5')

# %% [markdown]
# ###Make ibound array for Layer 6

# %%
ibnd_l6 = ext_FAS
np.savetxt(os.path.join(ref_dir, 'fasgas_ibnd_L6.ref'), ibnd_l6, fmt=fmt)
fasgas_plotter.plot_image(array=ibnd_l6, title='ibound layer 6')

# %% [markdown]
# ###Make ibound array for Layer 7

# %%
ibnd_l7 = ext_FAS
np.savetxt(os.path.join(ref_dir, 'fasgas_ibnd_L7.ref'), ibnd_l7, fmt=fmt)
fasgas_plotter.plot_image(array=ibnd_l7, title='ibound layer 7')

# %% [markdown]
# ###Make ibound array for Layer 8

# %%
ibnd_l8 = np.zeros((nrow, ncol), dtype=np.int)

# Set active using the union of the GLAUCU and OLDSPZ
x, y = np.where((ext_GLAUCU==1) | (ext_OLDSPZ==1))
ibnd_l8[x, y] = 1

np.savetxt(os.path.join(ref_dir, 'fasgas_ibnd_L8.ref'), ibnd_l8, fmt=fmt)
fasgas_plotter.plot_image(array=ibnd_l8, title='ibound layer 8')

# %% [markdown]
# ###Make ibound array for Layer 9

# %%
ibnd_l9 = np.zeros((nrow, ncol), dtype=np.int)

# Set active using the union of the GLAUCU and OLDSPZ
x, y = np.where((ext_GLAUCU==1) | (ext_OLDSPZ==1))
ibnd_l9[x, y] = 1

np.savetxt(os.path.join(ref_dir, 'fasgas_ibnd_L9.ref'), ibnd_l9, fmt=fmt)
fasgas_plotter.plot_image(array=ibnd_l9, title='ibound layer 9')
